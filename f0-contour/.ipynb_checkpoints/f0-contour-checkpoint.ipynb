# %%
import parselmouth

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os.path

sns.set() # Use seaborn's default style to make attractive graphs

# %%
# Plot nice figures using Python's "standard" matplotlib library
snd = parselmouth.Sound("vits_5.wav")
plt.figure()
plt.plot(snd.xs(), snd.values.T)
plt.xlim([snd.xmin, snd.xmax])
plt.xlabel("time [s]")
plt.ylabel("amplitude")
plt.show() # or plt.savefig("sound.png"), or plt.savefig("sound.pdf")

# %%
def draw_spectrogram(spectrogram, dynamic_range=70):
    X, Y = spectrogram.x_grid(), spectrogram.y_grid()
    sg_db = 10 * np.log10(spectrogram.values)
    plt.pcolormesh(X, Y, sg_db, vmin=sg_db.max() - dynamic_range, cmap='viridis')
    plt.ylim([spectrogram.ymin, spectrogram.ymax])
    plt.xlabel("time [s]")
    #plt.ylabel("frequency [Hz]")

# %%
def draw_intensity(intensity, color='b'):
    #plt.plot(intensity.xs(), intensity.values.T, linewidth=3, color='w')
    plt.plot(intensity.xs(), intensity.values.T, linewidth=2, color=color)
    plt.grid(True)
    plt.ylim(0)
    plt.ylabel("intensity [dB]")

# %%
def draw_pitch(pitch, color='b'):
    # Extract selected pitch contour, and
    # replace unvoiced samples by NaN to not plot
    pitch_values = pitch.selected_array['frequency']
    #pitch_values[pitch_values==0] = np.nan
    #plt.plot(pitch.xs(), pitch_values, 'o', markersize=5, color='w')
    plt.plot(pitch.xs(), pitch_values, '-', markersize=1, color=color)
    plt.grid(True)
    plt.ylim(0, 500)
    plt.xlabel("Time [s]")
    plt.ylabel("F0 [Hz]")

# %%
colors = ['red', 'green', 'blue', 'brown', 'orange']
plt.figure()
#plt.tight_layout()

i = 0
ax1 = plt.subplot(2, 1, 1)
plt.title("(a) Proposed-2", y=1, fontsize=16)
for wave_file in glob.glob("vits-ad18-1/*.wav"):
    print("Processing {}...".format(wave_file))
    snd = parselmouth.Sound(wave_file)
    pitch = snd.to_pitch()
    pre_emphasized_snd = snd.copy()
    pre_emphasized_snd.pre_emphasize()
    spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)
    #intensity = pre_emphasized_snd.to_intensity()
    #plt.twinx()
    draw_pitch(pitch, colors[i])
    #draw_spectrogram(spectrogram)
    #draw_intensity(intensity, colors[i])
    plt.xlim([snd.xmin, snd.xmax])
    plt.legend(['Sample 1', 'Sample 2', 'Sample 3', 'Sample 4'], loc='best', bbox_to_anchor=(0.8, 0., 0.5, 0.5))
    i += 1

plt.subplots_adjust(hspace=1.5)

i = 0
ax2 = plt.subplot(2, 1, 2)
plt.title("(b) Tacotron-2", y=1, fontsize=16)
for wave_file in glob.glob("taco2-ad18/*.wav"):
    print("Processing {}...".format(wave_file))
    snd = parselmouth.Sound(wave_file)
    pitch = snd.to_pitch()
    pre_emphasized_snd = snd.copy()
    pre_emphasized_snd.pre_emphasize()
    spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)
    #intensity = pre_emphasized_snd.to_intensity()
    #plt.twinx()
    draw_pitch(pitch, colors[i])
    #draw_spectrogram(spectrogram)
    #draw_intensity(intensity, colors[i])
    plt.xlim([snd.xmin, snd.xmax])
    plt.legend(['Sample 1', 'Sample 2', 'Sample 3', 'Sample 4'], loc='best', bbox_to_anchor=(0.8, 0.6, 0.5, 0.5))
    i += 1
    
    
#plt.show()
plt.savefig("pitch-variation-final.png")
# Out:
# Processing vits-ad18-1/vits_1.wav...
# Processing vits-ad18-1/vits_2.wav...
# Processing vits-ad18-1/vits_3.wav...
# Processing vits-ad18-1/vits_4.wav...
# Processing taco2-ad18/taco2_1.wav...
# Processing taco2-ad18/taco2_2.wav...
# Processing taco2-ad18/taco2_3.wav...
# Processing taco2-ad18/taco2_4.wav...

# %%
colors = ['red', 'green', 'blue', 'brown', 'orange']
plt.figure()
#plt.tight_layout()

i = 0
ax1 = plt.subplot(2, 1, 1)
plt.title("(a) Proposed-2", y=1, fontsize=16)
for wave_file in glob.glob("vits-ad18-1/*.wav"):
    print("Processing {}...".format(wave_file))
    snd = parselmouth.Sound(wave_file)
    pitch = snd.to_pitch()
    pre_emphasized_snd = snd.copy()
    pre_emphasized_snd.pre_emphasize()
    spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)
    intensity = pre_emphasized_snd.to_intensity()
    #plt.twinx()
    #draw_pitch(pitch, colors[i])
    #draw_spectrogram(spectrogram)
    draw_intensity(intensity, colors[i])
    plt.xlim([snd.xmin, snd.xmax])
    plt.legend(['Sample 1', 'Sample 2', 'Sample 3', 'Sample 4'], loc='best', bbox_to_anchor=(0.8, 0.6, 0.5, 0.5))
    i += 1

plt.subplots_adjust(hspace=1.5)

i = 0
ax2 = plt.subplot(2, 1, 2)
plt.title("(b) Tacotron-2", y=1, fontsize=16)
for wave_file in glob.glob("taco2-ad18/*.wav"):
    print("Processing {}...".format(wave_file))
    snd = parselmouth.Sound(wave_file)
    pitch = snd.to_pitch()
    pre_emphasized_snd = snd.copy()
    pre_emphasized_snd.pre_emphasize()
    spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)
    intensity = pre_emphasized_snd.to_intensity()
    #plt.twinx()
    #draw_pitch(pitch, colors[i])
    #draw_spectrogram(spectrogram)
    draw_intensity(intensity, colors[i])
    plt.xlim([snd.xmin, snd.xmax])
    plt.legend(['Sample 1', 'Sample 2', 'Sample 3', 'Sample 4'], loc='best', bbox_to_anchor=(0.8, 0.6, 0.5, 0.5))
    i += 1
    
    
#plt.show()
plt.savefig("intensity.png")
# Out:
# Processing vits-ad18-1/vits_1.wav...
# Processing vits-ad18-1/vits_2.wav...
# Processing vits-ad18-1/vits_3.wav...
# Processing vits-ad18-1/vits_4.wav...
# Processing taco2-ad18/taco2_1.wav...
# Processing taco2-ad18/taco2_2.wav...
# Processing taco2-ad18/taco2_3.wav...
# Processing taco2-ad18/taco2_4.wav...

# %%
plt.figure()
#plt.tight_layout()

i = 1

for wave_file in glob.glob("vits-duration/*.wav"):
    plt.subplot(4, 1, i)
    #plt.figure()
    print("Processing {}...".format(wave_file))
    snd = parselmouth.Sound(wave_file)
    pitch = snd.to_pitch()
    pre_emphasized_snd = snd.copy()
    pre_emphasized_snd.pre_emphasize()
    spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)
    #intensity = pre_emphasized_snd.to_intensity()
    #plt.twinx()
    #draw_pitch(pitch, colors[i])
    draw_spectrogram(spectrogram)
    #draw_intensity(intensity, colors[i])
    plt.xlim([snd.xmin, snd.xmax])
#     plt.axis('off')
#     if i == 4: 
#         plt.axis('on')
#         #plt.axes.get_yaxis().set_visible(False)
    #plt.legend(['Sample 1', 'Sample 2', 'Sample 3', 'Sample 4'], loc='best', bbox_to_anchor=(0.8, 0.6, 0.5, 0.5))
    i += 1
    #if i == 2: break

plt.subplots_adjust(hspace=1.5)#, wspace=0.5)
plt.xlabel('time [s]')


    
plt.show()
#plt.savefig("intensity.png")
# Out:
# Processing vits-duration/1 kn30_vits_2.wav...
# /tmp/ipykernel_28653/880399538.py:3: RuntimeWarning: divide by zero encountered in log10
#   sg_db = 10 * np.log10(spectrogram.values)
# /tmp/ipykernel_28653/880399538.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolormesh(X, Y, sg_db, vmin=sg_db.max() - dynamic_range, cmap='viridis')
# Processing vits-duration/2 kn30_vits_1.5.wav...
# Processing vits-duration/kn30_vits-120k.wav...
# Processing vits-duration/kn30_vits_0.5.wav...

# %%
intensity = snd.to_intensity()
spectrogram = snd.to_spectrogram()
plt.figure()
draw_spectrogram(spectrogram)
plt.twinx()
draw_intensity(intensity)
plt.xlim([snd.xmin, snd.xmax])
plt.show() # or plt.savefig("spectrogram.pdf")

# %%
pitch = snd.to_pitch()
# If desired, pre-emphasize the sound fragment before calculating the spectrogram
pre_emphasized_snd = snd.copy()
pre_emphasized_snd.pre_emphasize()
spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)
plt.figure()
draw_spectrogram(spectrogram)
#plt.twinx()
draw_pitch(pitch)
plt.xlim([snd.xmin, snd.xmax])
plt.show() # or plt.savefig("spectrogram_0.03.pdf")
# Out:
# /tmp/ipykernel_3778/1863412086.py:3: RuntimeWarning: divide by zero encountered in log10
#   sg_db = 10 * np.log10(spectrogram.values)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3778/168847087.py in <module>
#       5 spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)
#       6 plt.figure()
# ----> 7 draw_spectrogram(spectrogram)
#       8 #plt.twinx()
#       9 draw_pitch(pitch)
#
# /tmp/ipykernel_3778/1863412086.py in draw_spectrogram(spectrogram, dynamic_range)
#       2     X, Y = spectrogram.x_grid(), spectrogram.y_grid()
#       3     sg_db = 10 * np.log10(spectrogram.values)
# ----> 4     plt.pcolormesh(X, Y, sg_db, vmin=sg_db.max() - dynamic_range, cmap='viridis', aspect='auto')
#       5     plt.ylim([spectrogram.ymin, spectrogram.ymax])
#       6     #plt.xlabel("time [s]")
#
# ~/anaconda3/envs/coqui/lib/python3.8/site-packages/matplotlib/pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2978         vmax=None, shading=None, antialiased=False, data=None,
#    2979         **kwargs):
# -> 2980     __ret = gca().pcolormesh(
#    2981         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2982         vmax=vmax, shading=shading, antialiased=antialiased,
#
# ~/anaconda3/envs/coqui/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/coqui/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6190         C = C.ravel()
#    6191         coords = np.column_stack((X, Y)).astype(float, copy=False)
# -> 6192         collection = mcoll.QuadMesh(Nx - 1, Ny - 1, coords,
#    6193                                     antialiased=antialiased, shading=shading,
#    6194                                     **kwargs)
#
# ~/anaconda3/envs/coqui/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, meshWidth, meshHeight, coordinates, antialiased, shading, **kwargs)
#    2001     def __init__(self, meshWidth, meshHeight, coordinates,
#    2002                  antialiased=True, shading='flat', **kwargs):
# -> 2003         super().__init__(**kwargs)
#    2004         self._meshWidth = meshWidth
#    2005         self._meshHeight = meshHeight
#
# ~/anaconda3/envs/coqui/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/envs/coqui/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     215
#     216         self._path_effects = None
# --> 217         self.update(kwargs)
#     218         self._paths = None
#     219
#
# ~/anaconda3/envs/coqui/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#    1060                     func = getattr(self, f"set_{k}", None)
#    1061                     if not callable(func):
# -> 1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
#    1064                     ret.append(func(v))
#
# AttributeError: 'QuadMesh' object has no property 'aspect'

# %%
for wave_file in glob.glob("*.wav"):
    print("Processing {}...".format(wave_file))
    s = parselmouth.Sound(wave_file)
#     s.pre_emphasize()
#     s.save(os.path.splitext(wave_file)[0] + "_pre.wav", 'WAV') # or parselmouth.SoundFileFormat.WAV instead of 'WAV'
#     s.save(os.path.splitext(wave_file)[0] + "_pre.aiff", 'AIFF')
# Out:
# Processing vits_1.wav...
# Processing vits_2.wav...
# Processing vits_3.wav...
# Processing vits_4.wav...
# Processing vits_5.wav...
